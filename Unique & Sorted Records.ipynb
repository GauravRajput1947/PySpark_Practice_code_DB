# %% [markdown]
# ### 1: How to find unique rows
# ### 2: How to drop duplicates rows?
# ### 3: How to sort the data in ascending and descending order?

# %%
Manager_df=(
    spark.read.format("csv")\
         .option("header", "false")\
         .option("inferschema","true")\
         .option("mode", "FAILFAST")\
         .load("/Volumes/workspace/default/mngr_data/Manager.csv")
)

# %%
data=[(10 ,'Anil',50000, 18),
(11 ,'Vikas',75000,  16),
(12 ,'Nisha',40000,  18),
(13 ,'Nidhi',60000,  17),
(14 ,'Priya',80000,  18),
(15 ,'Mohit',45000,  18),
(16 ,'Rajesh',90000, 10),
(17 ,'Raman',55000, 16),
(18 ,'Sam',65000,   17),
(15 ,'Mohit',45000,  18),
(13 ,'Nidhi',60000,  17),      
(14 ,'Priya',90000,  18),  
(18 ,'Sam',65000,   17)
     ]
schema = ['id','name','sal','mngr_id']
Manager_df=spark.createDataFrame(data=data,schema=schema)

# %%
Manager_df.show()

# %% [markdown]
# ### If i want to find record is duplicate or not : we use Distinct where find our record is different

# %%
Manager_df.distinct().show()

# %%
Manager_df.count()

# %%
Manager_df.distinct().count()

# %%
# I want to search in such column

Manager_df.distinct("id","name").show()

# %%
Manager_df.select("id","name").distinct().show()

# %% [markdown]
# ### Drop Duplicate Records

# %% [markdown]
# ### after drop , I have to save in another Dataframe because prvious changing is not showing in old df.

# %%
Manager_df.drop_duplicates(["id","name","sal","mngr_id"]).show()

# %% [markdown]
# after drop , I have to save in another DF because previous Changing is not showing in OLd DF

# %%
dropped_Manger_df = Manager_df.drop_duplicates(["id","name","sal","mngr_id"])
dropped_Manger_df.show()

# %% [markdown]
# from next I will use this DataFrame . Dropped_mngr_data. if i use previous Dataframe .it doesn't seem effect because Df is immutable .
# Immutable--->I can Overwrite but I can't update/changes.

# %% [markdown]
# Sort Data In ASC and DESC

# %%
from pyspark.sql.functions import*
from pyspark.sql.types import*

# %%
Manager_df.sort(col("sal")).show()

# %%
Manager_df.sort(col("sal").desc()).show()

# %%
# i want to sort by sal and name 

Manager_df.sort(col("id"),col("name"),col("sal"),col("mngr_id")).show()
